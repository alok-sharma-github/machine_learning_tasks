# %%
ques = """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
Python Fundamentals
Python libraries for Data Science
Data Analysis
SQL for Data Science
Maths for Machine Learning
ML Algorithms
Practical ML
MLOPs
Case studies
You can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-Data-Science-Mentorship-Program-637339afe4b0615a1bbed390
Will Deep Learning and NLP be a part of this program?
No, NLP and Deep Learning both are not a part of this program’s curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?
Checkout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/16OoTax_A6ORAeCg4emgexhqqPv3noQPYKU7RJ6ArOzk/edit?usp=sharing.
What is the time duration of all the live sessions?
Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail us at nitish.campusx@gmail.com
Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/
Can we pay the entire amount of Rs 5600 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
What if I don’t like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmail.com
Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmai.com
Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5600
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?
This is to clarify that Placement assistance does not mean Placement guarantee. So we dont guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance
Portfolio Building sessions
Soft skill sessions
Sessions with industry mentors
Discussion on Job hunting strategies
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([ques])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'you': 2,
#  'i': 3,
#  'to': 4,
#  'a': 5,
#  'of': 6,
#  'is': 7,
#  'have': 8,
#  'will': 9,
#  'can': 10,
#  'what': 11,
#  'course': 12,
#  'program': 13,
#  'in': 14,
#  'for': 15,
#  'all': 16,
#  'sessions': 17,
#  'on': 18,
#  'be': 19,
#  'and': 20,
#  'this': 21,
#  'if': 22,
#  'am': 23,
#  'pay': 24,
#  'payment': 25,
#  'make': 26,
#  'we': 27,
#  'do': 28,
#  'subscription': 29,
#  'where': 30,
#  'rs': 31,
#  'so': 32,
#  'campusx': 33,
#  'session': 34,
#  'our': 35,
#  'paid': 36,
#  'join': 37,
#  'able': 38,
#  'your': 39,
#  'website': 40,
#  'placement': 41,
#  'fee': 42,
#  'data': 43,
#  'monthly': 44,
#  'month': 45,
#  'not': 46,
#  'get': 47,
#  'yes': 48,
#  'once': 49,
#  'past': 50,
#  'feb': 51,
#  'assistance': 52,
#  'science': 53,
#  '7': 54,
#  '5600': 55,
#  'are': 56,
#  'watch': 57,
#  'google': 58,
#  'by': 59,
#  'com': 60,
#  'mail': 61,
#  'from': 62,
#  'contact': 63,
#  'us': 64,
#  'at': 65,
#  'or': 66,
#  'doubt': 67,
#  'mentorship': 68,
#  'payments': 69,
#  '799': 70,
#  'total': 71,
#  'duration': 72,
#  'months': 73,
#  'learning': 74,
#  'case': 75,
#  'here': 76,
#  'https': 77,
#  'part': 78,
#  'see': 79,
#  'late': 80,
#  'dashboard': 81,
#  'task': 82,
#  'don’t': 83,
#  'nitish': 84,
#  'validity': 85,
#  '15th': 86,
#  'jan': 87,
#  'period': 88,
#  'after': 89,
#  'till': 90,
#  '21st': 91,
#  'that': 92,
#  'about': 93,
#  'follows': 94,
#  'model': 95,
#  'syllabus': 96,
#  'python': 97,
#  'ml': 98,
#  'studies': 99,
#  'learnwith': 100,
#  'deep': 101,
#  'nlp': 102,
#  'no': 103,
#  'miss': 104,
#  'live': 105,
#  'recording': 106,
#  'even': 107,
#  'class': 108,
#  'time': 109,
#  '2': 110,
#  'how': 111,
#  'absolutely': 112,
#  'middle': 113,
#  'anytime': 114,
#  'submit': 115,
#  'with': 116,
#  'gmail': 117,
#  'registration': 118,
#  'related': 119,
#  'link': 120,
#  'entire': 121,
#  'suppose': 122,
#  'again': 123,
#  'days': 124,
#  'day': 125,
#  'refund': 126,
#  'living': 127,
#  'outside': 128,
#  'india': 129,
#  'should': 130,
#  'sending': 131,
#  'queries': 132,
#  'videos': 133,
#  'read': 134,
#  'but': 135,
#  'provided': 136,
#  'form': 137,
#  '1': 138,
#  'clearance': 139,
#  'week': 140,
#  'just': 141,
#  'certificate': 142,
#  'earlier': 143,
#  'comes': 144,
#  'under': 145,
#  'guarantee': 146,
#  'dsmp': 147,
#  '2023': 148,
#  'becomes': 149,
#  'approx': 150,
#  'covering': 151,
#  'following': 152,
#  'modules': 153,
#  'fundamentals': 154,
#  'libraries': 155,
#  'analysis': 156,
#  'sql': 157,
#  'maths': 158,
#  'machine': 159,
#  'algorithms': 160,
#  'practical': 161,
#  'mlops': 162,
#  'check': 163,
#  'detailed': 164,
#  'courses': 165,
#  '637339afe4b0615a1bbed390': 166,
#  'both': 167,
#  'program’s': 168,
#  'curriculum': 169,
#  'recorded': 170,
#  'go': 171,
#  'back': 172,
#  'find': 173,
#  'schedule': 174,
#  'checkout': 175,
#  'sheet': 176,
#  'table': 177,
#  'docs': 178,
#  'spreadsheets': 179,
#  'd': 180,
#  '16ootax': 181,
#  'a6oraecg4emgexhqqpv3noqpyku7rj6arozk': 182,
#  'edit': 183,
#  'usp': 184,
#  'sharing': 185,
#  'roughly': 186,
#  'last': 187,
#  'hours': 188,
#  'language': 189,
#  'spoken': 190,
#  'instructor': 191,
#  'during': 192,
#  'hinglish': 193,
#  'informed': 194,
#  'upcoming': 195,
#  'side': 196,
#  'before': 197,
#  'every': 198,
#  'become': 199,
#  'user': 200,
#  'non': 201,
#  'tech': 202,
#  'background': 203,
#  'lectures': 204,
#  'content': 205,
#  'provide': 206,
#  'solutions': 207,
#  'self': 208,
#  'evaluate': 209,
#  'yourself': 210,
#  'questions': 211,
#  'youtube': 212,
#  'channel': 213,
#  'amount': 214,
#  'unfortunately': 215,
#  'then': 216,
#  '1st': 217,
#  '30': 218,
#  'essentially': 219,
#  'wait': 220,
#  'end': 221,
#  'like': 222,
#  'making': 223,
#  'policy': 224,
#  'made': 225,
#  'post': 226,
#  'when': 227,
#  'view': 228,
#  'one': 229,
#  'tricky': 230,
#  'carefully': 231,
#  'valid': 232,
#  'purchased': 233,
#  '20th': 234,
#  'purchase': 235,
#  'over': 236,
#  'installments': 237,
#  'aug': 238,
#  '2024': 239,
#  'why': 240,
#  'lifetime': 241,
#  'because': 242,
#  'low': 243,
#  'reach': 244,
#  'out': 245,
#  'fill': 246,
#  'team': 247,
#  'still': 248,
#  'ask': 249,
#  'doubts': 250,
#  'select': 251,
#  'gmai': 252,
#  'criteria': 253,
#  'there': 254,
#  'criterias': 255,
#  'attempt': 256,
#  'assessments': 257,
#  'joining': 258,
#  'current': 259,
#  'clarify': 260,
#  'does': 261,
#  'mean': 262,
#  'dont': 263,
#  'any': 264,
#  'jobs': 265,
#  'matter': 266,
#  'interview': 267,
#  'calls': 268,
#  'planning': 269,
#  'placements': 270,
#  'afraid': 271,
#  'disappointed': 272,
#  'portfolio': 273,
#  'building': 274,
#  'soft': 275,
#  'skill': 276,
#  'industry': 277,
#  'mentors': 278,
#  'discussion': 279,
#  'job': 280,
#  'hunting': 281,
#  'strategies': 282}

# %%
input_sequence = []
for sent in ques.split("\n"):
    print(sent)
    tokenized_sent = tokenizer.texts_to_sequences([sent])[0]
    print(tokenized_sent)
    for i in range(1,len(tokenized_sent)):
        input_sequence.append(tokenized_sent[:i+1])
# Out:
# About the Program
# [93, 1, 13]
# What is the course fee for  Data Science Mentorship Program (DSMP 2023)
# [11, 7, 1, 12, 42, 15, 43, 53, 68, 13, 147, 148]
# The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
# [1, 12, 94, 5, 44, 29, 95, 30, 2, 8, 4, 26, 44, 69, 6, 31, 70, 45]
# What is the total duration of the course?
# [11, 7, 1, 71, 72, 6, 1, 12]
# The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
# [1, 71, 72, 6, 1, 12, 7, 54, 73, 32, 1, 71, 12, 42, 149, 70, 54, 31, 55, 150]
# What is the syllabus of the mentorship program?
# [11, 7, 1, 96, 6, 1, 68, 13]
# We will be covering the following modules:
# [27, 9, 19, 151, 1, 152, 153]
# Python Fundamentals
# [97, 154]
# Python libraries for Data Science
# [97, 155, 15, 43, 53]
# Data Analysis
# [43, 156]
# SQL for Data Science
# [157, 15, 43, 53]
# Maths for Machine Learning
# [158, 15, 159, 74]
# ML Algorithms
# [98, 160]
# Practical ML
# [161, 98]
# MLOPs
# [162]
# Case studies
# [75, 99]
# You can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-Data-Science-Mentorship-Program-637339afe4b0615a1bbed390
# [2, 10, 163, 1, 164, 96, 76, 77, 100, 33, 14, 165, 33, 43, 53, 68, 13, 166]
# Will Deep Learning and NLP be a part of this program?
# [9, 101, 74, 20, 102, 19, 5, 78, 6, 21, 13]
# No, NLP and Deep Learning both are not a part of this program’s curriculum.
# [103, 102, 20, 101, 74, 167, 56, 46, 5, 78, 6, 21, 168, 169]
# What if I miss a live session? Will I get a recording of the session?
# [11, 22, 3, 104, 5, 105, 34, 9, 3, 47, 5, 106, 6, 1, 34]
# Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
# [48, 16, 35, 17, 56, 170, 32, 107, 22, 2, 104, 5, 34, 2, 10, 171, 172, 20, 57, 1, 106]
# Where can I find the class schedule?
# [30, 10, 3, 173, 1, 108, 174]
# Checkout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/16OoTax_A6ORAeCg4emgexhqqPv3noQPYKU7RJ6ArOzk/edit?usp=sharing.
# [175, 21, 58, 176, 4, 79, 45, 59, 45, 109, 177, 6, 1, 12, 77, 178, 58, 60, 179, 180, 181, 182, 183, 184, 185]
# What is the time duration of all the live sessions?
# [11, 7, 1, 109, 72, 6, 16, 1, 105, 17]
# Roughly, all the sessions last 2 hours.
# [186, 16, 1, 17, 187, 110, 188]
# What is the language spoken by the instructor during the sessions?
# [11, 7, 1, 189, 190, 59, 1, 191, 192, 1, 17]
# Hinglish
# [193]
# How will I be informed about the upcoming class?
# [111, 9, 3, 19, 194, 93, 1, 195, 108]
# You will get a mail from our side before every paid session once you become a paid user.
# [2, 9, 47, 5, 61, 62, 35, 196, 197, 198, 36, 34, 49, 2, 199, 5, 36, 200]
# Can I do this course if I am from a non-tech background?
# [10, 3, 28, 21, 12, 22, 3, 23, 62, 5, 201, 202, 203]
# Yes, absolutely.
# [48, 112]
# I am late, can I join the program in the middle?
# [3, 23, 80, 10, 3, 37, 1, 13, 14, 1, 113]
# Absolutely, you can join the program anytime.
# [112, 2, 10, 37, 1, 13, 114]
# If I join/pay in the middle, will I be able to see all the past lectures?
# [22, 3, 37, 24, 14, 1, 113, 9, 3, 19, 38, 4, 79, 16, 1, 50, 204]
# Yes, once you make the payment you will be able to see all the past content in your dashboard.
# [48, 49, 2, 26, 1, 25, 2, 9, 19, 38, 4, 79, 16, 1, 50, 205, 14, 39, 81]
# Where do I have to submit the task?
# [30, 28, 3, 8, 4, 115, 1, 82]
# You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
# [2, 83, 8, 4, 115, 1, 82, 27, 9, 206, 2, 116, 1, 207, 2, 8, 4, 208, 209, 1, 82, 210]
# Will we do case studies in the program?
# [9, 27, 28, 75, 99, 14, 1, 13]
# Yes.
# [48]
# Where can we contact you?
# [30, 10, 27, 63, 2]
# You can mail us at nitish.campusx@gmail.com
# [2, 10, 61, 64, 65, 84, 33, 117, 60]
# Payment/Registration related questions
# [25, 118, 119, 211]
# Where do we have to make our payments? Your YouTube channel or website?
# [30, 28, 27, 8, 4, 26, 35, 69, 39, 212, 213, 66, 40]
# You have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/
# [2, 8, 4, 26, 16, 39, 44, 69, 18, 35, 40, 76, 7, 1, 120, 15, 35, 40, 77, 100, 33, 14]
# Can we pay the entire amount of Rs 5600 all at once?
# [10, 27, 24, 1, 121, 214, 6, 31, 55, 16, 65, 49]
# Unfortunately no, the program follows a monthly subscription model.
# [215, 103, 1, 13, 94, 5, 44, 29, 95]
# What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
# [11, 7, 1, 85, 6, 44, 29, 122, 22, 3, 24, 18, 86, 87, 216, 28, 3, 8, 4, 24, 123, 18, 217, 51, 66, 86, 51]
# 15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
# [86, 51, 1, 85, 88, 7, 218, 124, 62, 1, 125, 2, 26, 1, 25, 32, 219, 2, 10, 37, 114, 2, 83, 8, 4, 220, 15, 5, 45, 4, 221]
# What if I don’t like the course after making the payment. What is the refund policy?
# [11, 22, 3, 83, 222, 1, 12, 89, 223, 1, 25, 11, 7, 1, 126, 224]
# You get a 7 days refund period from the day you have made the payment.
# [2, 47, 5, 54, 124, 126, 88, 62, 1, 125, 2, 8, 225, 1, 25]
# I am living outside India and I am not able to make the payment on the website, what should I do?
# [3, 23, 127, 128, 129, 20, 3, 23, 46, 38, 4, 26, 1, 25, 18, 1, 40, 11, 130, 3, 28]
# You have to contact us by sending a mail at nitish.campusx@gmail.com
# [2, 8, 4, 63, 64, 59, 131, 5, 61, 65, 84, 33, 117, 60]
# Post registration queries
# [226, 118, 132]
# Till when can I view the paid videos on the website?
# [90, 227, 10, 3, 228, 1, 36, 133, 18, 1, 40]
# This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
# [21, 229, 7, 230, 32, 134, 231, 2, 10, 57, 1, 133, 90, 39, 29, 7, 232, 122, 2, 8, 233, 29, 18, 91, 87, 2, 9, 19, 38, 4, 57, 16, 1, 50, 36, 17, 14, 1, 88, 6, 91, 87, 4, 234, 51, 135, 89, 91, 51, 2, 9, 8, 4, 235, 1, 29, 123]
# But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
# [135, 49, 1, 12, 7, 236, 20, 2, 8, 36, 64, 31, 55, 66, 54, 237, 6, 31, 70, 2, 9, 19, 38, 4, 57, 1, 36, 17, 90, 238, 239]
# Why lifetime validity is not provided?
# [240, 241, 85, 7, 46, 136]
# Because of the low course fee.
# [242, 6, 1, 243, 12, 42]
# Where can I reach out in case of a doubt after the session?
# [30, 10, 3, 244, 245, 14, 75, 6, 5, 67, 89, 1, 34]
# You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
# [2, 9, 8, 4, 246, 5, 58, 137, 136, 14, 39, 81, 20, 35, 247, 9, 63, 2, 15, 5, 138, 18, 138, 67, 139, 34]
# If I join the program late, can I still ask past week doubts?
# [22, 3, 37, 1, 13, 80, 10, 3, 248, 249, 50, 140, 250]
# Yes, just select past week doubt in the doubt clearance google form.
# [48, 141, 251, 50, 140, 67, 14, 1, 67, 139, 58, 137]
# I am living outside India and I am not able to make the payment on the website, what should I do?
# [3, 23, 127, 128, 129, 20, 3, 23, 46, 38, 4, 26, 1, 25, 18, 1, 40, 11, 130, 3, 28]
# You have to contact us by sending a mail at nitish.campusx@gmai.com
# [2, 8, 4, 63, 64, 59, 131, 5, 61, 65, 84, 33, 252, 60]
# Certificate and Placement Assistance related queries
# [142, 20, 41, 52, 119, 132]
# What is the criteria to get the certificate?
# [11, 7, 1, 253, 4, 47, 1, 142]
# There are 2 criterias:
# [254, 56, 110, 255]
# You have to pay the entire fee of Rs 5600
# [2, 8, 4, 24, 1, 121, 42, 6, 31, 55]
# You have to attempt all the course assessments.
# [2, 8, 4, 256, 16, 1, 12, 257]
# I am joining late. How can I pay payment of the earlier months?
# [3, 23, 258, 80, 111, 10, 3, 24, 25, 6, 1, 143, 73]
# You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
# [2, 9, 47, 5, 120, 4, 24, 42, 6, 143, 73, 14, 39, 81, 49, 2, 24, 15, 1, 259, 45]
# I have read that Placement assistance is a part of this program. What comes under Placement assistance?
# [3, 8, 134, 92, 41, 52, 7, 5, 78, 6, 21, 13, 11, 144, 145, 41, 52]
# This is to clarify that Placement assistance does not mean Placement guarantee. So we dont guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance
# [21, 7, 4, 260, 92, 41, 52, 261, 46, 262, 41, 146, 32, 27, 263, 146, 2, 264, 265, 66, 15, 92, 266, 107, 267, 268, 32, 22, 2, 56, 269, 4, 37, 21, 12, 141, 15, 270, 3, 23, 271, 2, 9, 19, 272, 76, 7, 11, 144, 145, 41, 52]
# Portfolio Building sessions
# [273, 274, 17]
# Soft skill sessions
# [275, 276, 17]
# Sessions with industry mentors
# [17, 116, 277, 278]
# Discussion on Job hunting strategies
# [279, 18, 280, 281, 282]
#
# []

# %%
input_sequence.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 input_sequence.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %% [markdown]
# # Padding

# %%
max_len = max([len(i) for i in input_sequence])
print(max_len)
# Out:
# 57

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_seq = pad_sequences(input_sequence, maxlen = max_len)
print(padded_seq)
# Out:
# [[  0   0   0 ...   0  93   1]
#  [  0   0   0 ...  93   1  13]
#  [  0   0   0 ...   0  11   7]
#  ...
#  [  0   0   0 ... 279  18 280]
#  [  0   0   0 ...  18 280 281]
#  [  0   0   0 ... 280 281 282]]

# %%
X = padded_seq[:,:-1]# all columns
y = padded_seq[:,-1]# rowwise
print(f"Shape of X is {X.shape} and shape of y is {y.shape}")
# Out:
# Shape of X is (863, 56) and shape of y is (863,)

# %% [markdown]
# OHE

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes= len(tokenizer.word_index)+1)
print("shape y: ", y.shape)
# Out:
# shape y:  (863, 283)

# %% [markdown]
# # mOdle/

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding

model = Sequential()
model.add(Embedding(283, 100, input_length = 56))
model.add(LSTM(160))
model.add(Dense(283,activation = "softmax"))

model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 56, 100)           28300
#
#  lstm (LSTM)                 (None, 160)               167040
#
#  dense (Dense)               (None, 283)               45563
#
# =================================================================
# Total params: 240,903
# Trainable params: 240,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

filepath = "best_model.h5"

checkpoint = ModelCheckpoint(filepath, monitor='accuracy', verbose=1, save_best_only=True, mode='max')
history = model.fit(X, y, epochs=900, batch_size=32, callbacks=[checkpoint])
# Out:
# Epoch 1/900
# 27/27 [==============================] - ETA: 0s - loss: 5.4374 - accuracy: 0.0672
# Epoch 1: accuracy improved from -inf to 0.06721, saving model to best_model.h5
# 27/27 [==============================] - 4s 79ms/step - loss: 5.4374 - accuracy: 0.0672
# Epoch 2/900
# 27/27 [==============================] - ETA: 0s - loss: 5.0882 - accuracy: 0.0776
# Epoch 2: accuracy improved from 0.06721 to 0.07764, saving model to best_model.h5
# 27/27 [==============================] - 2s 83ms/step - loss: 5.0882 - accuracy: 0.0776
# Epoch 3/900
# 27/27 [==============================] - ETA: 0s - loss: 5.0183 - accuracy: 0.0776
# Epoch 3: accuracy did not improve from 0.07764
# 27/27 [==============================] - 2s 81ms/step - loss: 5.0183 - accuracy: 0.0776
# Epoch 4/900
# 27/27 [==============================] - ETA: 0s - loss: 4.9842 - accuracy: 0.0776
# Epoch 4: accuracy did not improve from 0.07764
# 27/27 [==============================] - 2s 81ms/step - loss: 4.9842 - accuracy: 0.0776
# Epoch 5/900
# 27/27 [==============================] - ETA: 0s - loss: 4.9358 - accuracy: 0.0776
# Epoch 5: accuracy did not improve from 0.07764
# 27/27 [==============================] - 2s 82ms/step - loss: 4.9358 - accuracy: 0.0776
# Epoch 6/900
# 27/27 [==============================] - ETA: 0s - loss: 4.8475 - accuracy: 0.0823
# Epoch 6: accuracy improved from 0.07764 to 0.08227, saving model to best_model.h5
# 27/27 [==============================] - 2s 82ms/step - loss: 4.8475 - accuracy: 0.0823
# Epoch 7/900
# 27/27 [==============================] - ETA: 0s - loss: 4.6965 - accuracy: 0.1101
# Epoch 7: accuracy improved from 0.08227 to 0.11008, saving model to best_model.h5
# 27/27 [==============================] - 2s 85ms/step - loss: 4.6965 - accuracy: 0.1101
# Epoch 8/900
# 27/27 [==============================] - ETA: 0s - loss: 4.4832 - accuracy: 0.1472
# Epoch 8: accuracy improved from 0.11008 to 0.14716, saving model to best_model.h5
# 27/27 [==============================] - 2s 82ms/step - loss: 4.4832 - accuracy: 0.1472
# Epoch 9/900
# 27/27 [==============================] - ETA: 0s - loss: 4.2562 - accuracy: 0.1773
# Epoch 9: accuracy improved from 0.14716 to 0.17729, saving model to best_model.h5
# 27/27 [==============================] - 2s 84ms/step - loss: 4.2562 - accuracy: 0.1773
# Epoch 10/900
# 27/27 [==============================] - ETA: 0s - loss: 4.0193 - accuracy: 0.2039
# Epoch 10: accuracy improved from 0.17729 to 0.20394, saving model to best_model.h5
# 27/27 [==============================] - 2s 77ms/step - loss: 4.0193 - accuracy: 0.2039
# Epoch 11/900
# 27/27 [==============================] - ETA: 0s - loss: 3.7780 - accuracy: 0.2329
# Epoch 11: accuracy improved from 0.20394 to 0.23291, saving model to best_model.h5
# 27/27 [==============================] - 2s 86ms/step - loss: 3.7780 - accuracy: 0.2329
# Epoch 12/900
# 27/27 [==============================] - ETA: 0s - loss: 3.5226 - accuracy: 0.2642
# Epoch 12: accuracy improved from 0.23291 to 0.26419, saving model to best_model.h5
# 27/27 [==============================] - 2s 92ms/step - loss: 3.5226 - accuracy: 0.2642
# Epoch 13/900
# 27/27 [==============================] - ETA: 0s - loss: 3.2943 - accuracy: 0.2955
# Epoch 13: accuracy improved from 0.26419 to 0.29548, saving model to best_model.h5
# 27/27 [==============================] - 2s 89ms/step - loss: 3.2943 - accuracy: 0.2955
# Epoch 14/900
# 27/27 [==============================] - ETA: 0s - loss: 3.0618 - accuracy: 0.3407
# Epoch 14: accuracy improved from 0.29548 to 0.34067, saving model to best_model.h5
# 27/27 [==============================] - 2s 81ms/step - loss: 3.0618 - accuracy: 0.3407
# Epoch 15/900
# 27/27 [==============================] - ETA: 0s - loss: 2.8459 - accuracy: 0.3685
# Epoch 15: accuracy improved from 0.34067 to 0.36848, saving model to best_model.h5
# 27/27 [==============================] - 2s 78ms/step - loss: 2.8459 - accuracy: 0.3685
# Epoch 16/900
# 27/27 [==============================] - ETA: 0s - loss: 2.6433 - accuracy: 0.4264
# Epoch 16: accuracy improved from 0.36848 to 0.42642, saving model to best_model.h5
# 27/27 [==============================] - 2s 76ms/step - loss: 2.6433 - accuracy: 0.4264
# Epoch 17/900
# 27/27 [==============================] - ETA: 0s - loss: 2.4699 - accuracy: 0.4461
# Epoch 17: accuracy improved from 0.42642 to 0.44612, saving model to best_model.h5
# 27/27 [==============================] - 2s 82ms/step - loss: 2.4699 - accuracy: 0.4461
# Epoch 18/900
# 27/27 [==============================] - ETA: 0s - loss: 2.2892 - accuracy: 0.4913
# Epoch 18: accuracy improved from 0.44612 to 0.49131, saving model to best_model.h5
# 27/27 [==============================] - 2s 82ms/step - loss: 2.2892 - accuracy: 0.4913
# Epoch 19/900
# 27/27 [==============================] - ETA: 0s - loss: 2.1289 - accuracy: 0.5504
# Epoch 19: accuracy improved from 0.49131 to 0.55041, saving model to best_model.h5
# 27/27 [==============================] - 2s 72ms/step - loss: 2.1289 - accuracy: 0.5504
# Epoch 20/900
# 27/27 [==============================] - ETA: 0s - loss: 1.9850 - accuracy: 0.5863
# Epoch 20: accuracy improved from 0.55041 to 0.58633, saving model to best_model.h5
# 27/27 [==============================] - 2s 80ms/step - loss: 1.9850 - accuracy: 0.5863
# Epoch 21/900
# 27/27 [==============================] - ETA: 0s - loss: 1.8375 - accuracy: 0.6130
# Epoch 21: accuracy improved from 0.58633 to 0.61298, saving model to best_model.h5
# 27/27 [==============================] - 2s 82ms/step - loss: 1.8375 - accuracy: 0.6130
# Epoch 22/900
# 27/27 [==============================] - ETA: 0s - loss: 1.7082 - accuracy: 0.6385
# Epoch 22: accuracy improved from 0.61298 to 0.63847, saving model to best_model.h5
# 27/27 [==============================] - 2s 76ms/step - loss: 1.7082 - accuracy: 0.6385
# Epoch 23/900
# 27/27 [==============================] - ETA: 0s - loss: 1.5873 - accuracy: 0.6744
# Epoch 23: accuracy improved from 0.63847 to 0.67439, saving model to best_model.h5
# 27/27 [==============================] - 2s 71ms/step - loss: 1.5873 - accuracy: 0.6744
# Epoch 24/900
# 27/27 [==============================] - ETA: 0s - loss: 1.4725 - accuracy: 0.7092
# Epoch 24: accuracy improved from 0.67439 to 0.70915, saving model to best_model.h5
# 27/27 [==============================] - 2s 72ms/step - loss: 1.4725 - accuracy: 0.7092
# Epoch 25/900
# 27/27 [==============================] - ETA: 0s - loss: 1.3720 - accuracy: 0.7404
# Epoch 25: accuracy improved from 0.70915 to 0.74044, saving model to best_model.h5
# 27/27 [==============================] - 2s 74ms/step - loss: 1.3720 - accuracy: 0.7404
# Epoch 26/900
# 27/27 [==============================] - ETA: 0s - loss: 1.2725 - accuracy: 0.7625
# Epoch 26: accuracy improved from 0.74044 to 0.76246, saving model to best_model.h5
# 27/27 [==============================] - 2s 71ms/step - loss: 1.2725 - accuracy: 0.7625
# Epoch 27/900
# 27/27 [==============================] - ETA: 0s - loss: 1.1820 - accuracy: 0.7810
# Epoch 27: accuracy improved from 0.76246 to 0.78100, saving model to best_model.h5
# 27/27 [==============================] - 2s 77ms/step - loss: 1.1820 - accuracy: 0.7810
# Epoch 28/900
# 27/27 [==============================] - ETA: 0s - loss: 1.1028 - accuracy: 0.8076
# Epoch 28: accuracy improved from 0.78100 to 0.80765, saving model to best_model.h5
# 27/27 [==============================] - 2s 76ms/step - loss: 1.1028 - accuracy: 0.8076
# Epoch 29/900
# 27/27 [==============================] - ETA: 0s - loss: 1.0275 - accuracy: 0.8227
# Epoch 29: accuracy improved from 0.80765 to 0.82271, saving model to best_model.h5
# 27/27 [==============================] - 2s 75ms/step - loss: 1.0275 - accuracy: 0.8227
# Epoch 30/900
# 27/27 [==============================] - ETA: 0s - loss: 0.9595 - accuracy: 0.8528
# Epoch 30: accuracy improved from 0.82271 to 0.85284, saving model to best_model.h5
# 27/27 [==============================] - 2s 72ms/step - loss: 0.9595 - accuracy: 0.8528
# Epoch 31/900
# 27/27 [==============================] - ETA: 0s - loss: 0.8926 - accuracy: 0.8633
# Epoch 31: accuracy improved from 0.85284 to 0.86327, saving model to best_model.h5
# 27/27 [==============================] - 2s 78ms/step - loss: 0.8926 - accuracy: 0.8633
# Epoch 32/900
# 27/27 [==============================] - ETA: 0s - loss: 0.8334 - accuracy: 0.8737
# Epoch 32: accuracy improved from 0.86327 to 0.87370, saving model to best_model.h5
# 27/27 [==============================] - 2s 71ms/step - loss: 0.8334 - accuracy: 0.8737
# Epoch 33/900
# 27/27 [==============================] - ETA: 0s - loss: 0.7837 - accuracy: 0.8783
# Epoch 33: accuracy improved from 0.87370 to 0.87833, saving model to best_model.h5
# 27/27 [==============================] - 2s 74ms/step - loss: 0.7837 - accuracy: 0.8783
# Epoch 34/900
# 27/27 [==============================] - ETA: 0s - loss: 0.7285 - accuracy: 0.9050
# Epoch 34: accuracy improved from 0.87833 to 0.90498, saving model to best_model.h5
# 27/27 [==============================] - 2s 73ms/step - loss: 0.7285 - accuracy: 0.9050
# Epoch 35/900
# 27/27 [==============================] - ETA: 0s - loss: 0.6814 - accuracy: 0.9050
# Epoch 35: accuracy did not improve from 0.90498
# 27/27 [==============================] - 2s 71ms/step - loss: 0.6814 - accuracy: 0.9050
# Epoch 36/900
# 27/27 [==============================] - ETA: 0s - loss: 0.6409 - accuracy: 0.9143
# Epoch 36: accuracy improved from 0.90498 to 0.91425, saving model to best_model.h5
# 27/27 [==============================] - 2s 74ms/step - loss: 0.6409 - accuracy: 0.9143
# Epoch 37/900
# 27/27 [==============================] - ETA: 0s - loss: 0.6003 - accuracy: 0.9119
# Epoch 37: accuracy did not improve from 0.91425
# 27/27 [==============================] - 2s 75ms/step - loss: 0.6003 - accuracy: 0.9119
# Epoch 38/900
# 27/27 [==============================] - ETA: 0s - loss: 0.5703 - accuracy: 0.9119
# Epoch 38: accuracy did not improve from 0.91425
# 27/27 [==============================] - 2s 77ms/step - loss: 0.5703 - accuracy: 0.9119
# Epoch 39/900
# 27/27 [==============================] - ETA: 0s - loss: 0.5366 - accuracy: 0.9212
# Epoch 39: accuracy improved from 0.91425 to 0.92121, saving model to best_model.h5
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5366 - accuracy: 0.9212
# Epoch 40/900
# 27/27 [==============================] - ETA: 0s - loss: 0.5071 - accuracy: 0.9189
# Epoch 40: accuracy did not improve from 0.92121
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5071 - accuracy: 0.9189
# Epoch 41/900
# 27/27 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.9293
# Epoch 41: accuracy improved from 0.92121 to 0.92932, saving model to best_model.h5
# 27/27 [==============================] - 2s 72ms/step - loss: 0.4793 - accuracy: 0.9293
# Epoch 42/900
# 27/27 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.9316
# Epoch 42: accuracy improved from 0.92932 to 0.93163, saving model to best_model.h5
# 27/27 [==============================] - 2s 73ms/step - loss: 0.4495 - accuracy: 0.9316
# Epoch 43/900
# 27/27 [==============================] - ETA: 0s - loss: 0.4297 - accuracy: 0.9351
# Epoch 43: accuracy improved from 0.93163 to 0.93511, saving model to best_model.h5
# 27/27 [==============================] - 2s 82ms/step - loss: 0.4297 - accuracy: 0.9351
# Epoch 44/900
# 27/27 [==============================] - ETA: 0s - loss: 0.4100 - accuracy: 0.9397
# Epoch 44: accuracy improved from 0.93511 to 0.93975, saving model to best_model.h5
# 27/27 [==============================] - 2s 89ms/step - loss: 0.4100 - accuracy: 0.9397
# Epoch 45/900
# 27/27 [==============================] - ETA: 0s - loss: 0.3868 - accuracy: 0.9444
# Epoch 45: accuracy improved from 0.93975 to 0.94438, saving model to best_model.h5
# 27/27 [==============================] - 2s 84ms/step - loss: 0.3868 - accuracy: 0.9444
# Epoch 46/900
# 27/27 [==============================] - ETA: 0s - loss: 0.3695 - accuracy: 0.9432
# Epoch 46: accuracy did not improve from 0.94438
# 27/27 [==============================] - 2s 71ms/step - loss: 0.3695 - accuracy: 0.9432
# Epoch 47/900
# 27/27 [==============================] - ETA: 0s - loss: 0.3546 - accuracy: 0.9397
# Epoch 47: accuracy did not improve from 0.94438
# 27/27 [==============================] - 2s 72ms/step - loss: 0.3546 - accuracy: 0.9397
# Epoch 48/900
# 27/27 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.9467
# Epoch 48: accuracy improved from 0.94438 to 0.94670, saving model to best_model.h5
# 27/27 [==============================] - 2s 75ms/step - loss: 0.3371 - accuracy: 0.9467
# Epoch 49/900
# 27/27 [==============================] - ETA: 0s - loss: 0.3255 - accuracy: 0.9432
# Epoch 49: accuracy did not improve from 0.94670
# 27/27 [==============================] - 2s 68ms/step - loss: 0.3255 - accuracy: 0.9432
# Epoch 50/900
# 27/27 [==============================] - ETA: 0s - loss: 0.3131 - accuracy: 0.9455
# Epoch 50: accuracy did not improve from 0.94670
# 27/27 [==============================] - 2s 71ms/step - loss: 0.3131 - accuracy: 0.9455
# Epoch 51/900
# 27/27 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.9432
# Epoch 51: accuracy did not improve from 0.94670
# 27/27 [==============================] - 2s 71ms/step - loss: 0.3003 - accuracy: 0.9432
# Epoch 52/900
# 27/27 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.9455
# Epoch 52: accuracy did not improve from 0.94670
# 27/27 [==============================] - 2s 81ms/step - loss: 0.2898 - accuracy: 0.9455
# Epoch 53/900
# 27/27 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.9502
# Epoch 53: accuracy improved from 0.94670 to 0.95017, saving model to best_model.h5
# 27/27 [==============================] - 2s 72ms/step - loss: 0.2789 - accuracy: 0.9502
# Epoch 54/900
# 27/27 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9490
# Epoch 54: accuracy did not improve from 0.95017
# 27/27 [==============================] - 2s 74ms/step - loss: 0.2677 - accuracy: 0.9490
# Epoch 55/900
# 27/27 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.9432
# Epoch 55: accuracy did not improve from 0.95017
# 27/27 [==============================] - 2s 74ms/step - loss: 0.2609 - accuracy: 0.9432
# Epoch 56/900
# 27/27 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.9455
# Epoch 56: accuracy did not improve from 0.95017
# 27/27 [==============================] - 2s 80ms/step - loss: 0.2519 - accuracy: 0.9455
# Epoch 57/900
# 27/27 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.9409
# Epoch 57: accuracy did not improve from 0.95017
# 27/27 [==============================] - 2s 86ms/step - loss: 0.2454 - accuracy: 0.9409
# Epoch 58/900
# 27/27 [==============================] - ETA: 0s - loss: 0.2386 - accuracy: 0.9444
accuracy did not improve from 0.95133
# 27/27 [==============================] - 2s 72ms/step - loss: 0.0997 - accuracy: 0.9467
# Epoch 319/900
# 27/27 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9467
# Epoch 319: accuracy did not improve from 0.95133
# 27/27 [==============================] - 2s 76ms/step - loss: 0.0990 - accuracy: 0.9467
# Epoch 320/900
# 27/27 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9455
# Epoch 320: accuracy did not improve from 0.95133
# 27/27 [==============================] - 2s 72ms/step - loss: 0.0982 - accuracy: 0.9455
# Epoch 321/900
#  5/27 [====>.........................] - ETA: 1s - loss: 0.0831 - accuracy: 0.9500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 8>()
#       6 # Define the ModelCheckpoint callback to save the best model
#       7 checkpoint = ModelCheckpoint(filepath, monitor='accuracy', verbose=1, save_best_only=True, mode='max')
# ----> 8 history = model.fit(X, y, epochs=900, batch_size=32, callbacks=[checkpoint])
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File c:\Users\alok\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
for i in range(20):
    tokenized_text = tokenize.texts_to_sequence([text])[0]
    #padding
    padded_token = padded_seq([tokenized_text], maxlen=56)
    predicted_token = np.argmax(model.predict(padded_token))
    for word, index in token.word_index.items():
        if index == predicted_token:
            text = text + " " + word
            print(text)
